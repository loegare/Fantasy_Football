# %%
import requests
import pandas as pd
import numpy as np
import xml.etree.ElementTree as ET

# %%
stats=pd.read_excel('statid.xlsx')

# %%
games=[]
for j in range(1,18):
    print(j)
    url='http://www.nfl.com/ajax/scorestrip?season={}&seasonType={}&week={}'.format(2018,"REG",j)



    root=ET.fromstring(requests.get(url).text)


    for i in root[0]:
        games.append(i.attrib['eid'])

# %%
url='http://www.nfl.com/ajax/scorestrip?season={}&seasonType={}&week={}'.format(2018,"REG",1)
url

# %%
games=['2010121212']

# %%
gid=2018091000
# for gid in games:
url2='http://www.nfl.com/liveupdate/game-center/{}/{}_gtd.json'.format(gid,gid)

d=requests.get(url2).json()

df_d=[]
for key,val in d[str(gid)]['drives'].items():
    if key =='crntdrv':
        continue
    df=pd.DataFrame(val)[['start','end']].dropna()

    df2=pd.DataFrame([0])
    counter=0
    for i in df.columns:
        counter=0
        for j in df[i]:
            df2[i+' '+df[i].index[counter]]=j
            counter+=1
    df2=df2.drop([0,'start team','end team','end qtr'],axis=1)



    df=pd.DataFrame(val).drop(['plays','start','end'],axis=1).drop_duplicates()
    try:
        df=df.drop('redzone',axis=1)
    except:
        pass

    df=df.reset_index().drop('index',axis=1).reset_index()

    df2=df2.reset_index()

    df=pd.merge(df,df2,on='index').drop('index',axis=1)
    df['driveid']=key
    df_d.append(df)

# %%
df

# %%
df.pivot_table(index='defteam',aggfunc=sum,values='points')

# %%
piv=df3.pivot_table(index='playerName',aggfunc=sum,values='points').reset_index()
piv[(piv['playerName']=='NYJ')|(piv['playerName']=='DET')]

# %%
piv

# %%
# gid=2018120900
dfs=[]
# for gid in games:
#     print (gid)
#     url2='http://www.nfl.com/liveupdate/game-center/{}/{}_gtd.json'.format(gid,gid)

#     d=requests.get(url2).json()


#     for key,val in d[str(gid)]['drives'].items():
#         if key =='crntdrv':
#             continue

#         for key2,val2 in val['plays'].items():
#             for key3,val3 in val2['players'].items():
#                 df=(pd.DataFrame(val3))
#                 df['playerid']=key3
#                 df['play']=key2
#                 df['drive']=key
#                 df['description']=val2['desc']
#                 df['gid']=gid
#                 df['posteam']=val2['posteam']
#                 dfs.append(df)
# df=pd.concat(dfs)



# print (gid)
# url2='http://www.nfl.com/liveupdate/game-center/{}/{}_gtd.json'.format(gid,gid)

# d=requests.get(url2).json()


for key,val in d[str(gid)]['drives'].items():
    if key =='crntdrv':
        continue

    for key2,val2 in val['plays'].items():
        for key3,val3 in val2['players'].items():
            df=(pd.DataFrame(val3))
            df['playerid']=key3
            df['play']=key2
            df['drive']=key
            df['description']=val2['desc']
            df['posteam']=val2['posteam']
            dfs.append(df)
df=pd.concat(dfs)

# %%
url2

# %%
# df=pd.merge(df,stats,left_on='statId',right_on='id',how='left')

# df['play']=df['play'].astype(np.int64)

# df['points']=df['yds points'].fillna(0)*df['yards'].fillna(0)+df['existence points'].fillna(0)

# df['playerName'] = np.where(df['cat']=='defense', df['clubcode'],df['playerName'])

# piv=df.pivot_table(index='playerName',values=['points','yards'],aggfunc=sum)

# df.to_clipboard(sep='\t')

# %%
import statid

statdfs=[]
for key,val in statid.idmap.items():
    tdf=pd.DataFrame(val)
    tdf['statId']=key
    statdfs.append(tdf)

st=pd.concat(statdfs)

df2=pd.merge(df,st,on='statId',how='left')

df3=pd.merge(df2,pd.read_excel('points.xlsx'),
         left_on=['cat','fields'],
         right_on=['cat2','field']).\
drop({'cat_x','fields','cat2'},axis=1).\
    rename({'cat_y':'cat'},axis=1)

df3['points']=np.where(df3['cat']=='yds',df3['points']*df3['yards'],df3['points'])

df3['playerName']=np.where(df3['clubcode']==df3['posteam'],df3['playerName'],df3['clubcode'])

# %%
df3.to_csv('2018 Season.csv',index=False)

# %%
import requests
import pandas as pd
import numpy as np
import xml.etree.ElementTree as ET

# %%
games=[]
for j in range(1,2):
    print(j)
    url='http://www.nfl.com/ajax/scorestrip?season={}&seasonType={}&week={}'.format(2018,"REG",j)



    root=ET.fromstring(requests.get(url).text)


    for i in root[0]:
        games.append(i.attrib['eid'])
# Out:
# 1

# %%
games=['2010121212']

# %%
import statid
gid=2018120900
df_g=[]
drives=[]
for gid in games:
    print (gid)
    url2='http://www.nfl.com/liveupdate/game-center/{}/{}_gtd.json'.format(gid,gid)

    d=requests.get(url2).json()

    df_d=[]
    for key,val in d[str(gid)]['drives'].items():
        
        if key =='crntdrv':
            continue
        df=pd.DataFrame(val)[['start','end']].dropna()

        df2=pd.DataFrame([0])
        counter=0
        for i in df.columns:
            counter=0
            for j in df[i]:
                df2[i+' '+df[i].index[counter]]=j
                counter+=1
        df2=df2.drop([0,'start team','end team','end qtr'],axis=1)



        df=pd.DataFrame(val).drop(['plays','start','end'],axis=1).drop_duplicates()
        try:
            df=df.drop('redzone',axis=1)
        except:
            pass

        df=df.reset_index().drop('index',axis=1).reset_index()

        df2=df2.reset_index()

        df=pd.merge(df,df2,on='index').drop('index',axis=1)
        df['driveid']=key
        df_d.append(df)

        for key2,val2 in val['plays'].items():
            for key3,val3 in val2['players'].items():
                df=(pd.DataFrame(val3))
                df['playerid']=key3
                df['play']=key2
                df['drive']=key
                df['description']=val2['desc']
                df['gid']=gid
                df['posteam']=val2['posteam']
                df_g.append(df)
                
                
    df=pd.concat(df_d).fillna(0)

    df['posteam']=df['posteam'].str.pad(3,'right')
    df['start yrdln']=np.where(df['start yrdln']=='',df['posteam']+' 0',df['start yrdln'])
    df['start yrdln']=np.where(df['start yrdln']=='50',df['posteam']+' 50',df['start yrdln'])
    df['start yrdln']=df['start yrdln'].str.replace('  ',' ')

    df['start yrdln']=np.where(df['posteam']==df['start yrdln'].str[:3].str.strip(),
                               df['start yrdln'].str.split(' ').str[1],
                               (50-df['start yrdln'].str.split(' ').str[1].astype(np.int64))+50)

    df['end yrdln']=df['start yrdln'].astype(np.int64)+df['penyds'].astype(np.int64)+df['ydsgained'].astype(np.int64)
    df['gid']=gid



    dteam={d[str(gid)]['home']['abbr']:d[str(gid)]['away']['abbr'],
           d[str(gid)]['away']['abbr']:d[str(gid)]['home']['abbr'],
          '':''}

    df['defteam']=df['posteam'].str.strip().apply(lambda x: dteam[x])

    df['points']=0

    df['points']=np.where(df['fds']>0,df['points']-(.2*df['fds']),df['points'])

    df['points']=np.where(df['result']=='Touchdown',
                          np.where(df['start yrdln'].astype(np.int64)<50,
                                   df['points']-3,
                                   df['points']-1),df['points'])

    df['points']=np.where(df['result']=='Field Goal',
                          np.where(df['start yrdln'].astype(np.int64)<50,
                                   df['points']-1,
                                   df['points']-0),df['points'])

    df['points']=np.where((df['fds']==0)&((df['result']=='Punt')|
                                         (df['result']=='Fumble')|
                                         (df['result']=='Interception')),
                          df['points']+1,
                          df['points'])
    df['points']=np.where((df['result']=='Downs'),
                          df['points']+1,
                          df['points'])


    drives.append(df.copy())
df=pd.concat(df_g)
statdfs=[]
for key,val in statid.idmap.items():
    tdf=pd.DataFrame(val)
    tdf['statId']=key
    statdfs.append(tdf)

st=pd.concat(statdfs)

df2=pd.merge(df,st,on='statId',how='left')

# df3=pd.merge(df2,pd.read_excel('points.xlsx'),
#          left_on=['cat','fields'],
#          right_on=['cat2','field']).\
# drop({'cat_x','fields','cat2'},axis=1).\
#     rename({'cat_y':'cat'},axis=1)

df3=pd.merge(df2,pd.read_excel('points.xlsx'),
         left_on=['fields'],
         right_on=['field']).\
drop({'cat_x','fields','cat2'},axis=1).\
    rename({'cat_y':'cat'},axis=1)

df3['points']=np.where(df3['cat']=='yds',df3['points']*df3['yards'],df3['points'])
df3['playerName']=df3['playerName'].fillna(1)
df3['playerName']=np.where(df3['clubcode']==df3['posteam'],df3['playerName'],df3['clubcode'])
df3['playerName']=np.where(df3['playerName']==1,
                           np.where(df3['cat']=='defense',
                                    df3['posteam'].str.strip().apply(lambda x: dteam[x]),
                                    df3['clubcode']),
                          df3['playerName'])
plays=df3.copy()
drives=pd.concat(drives)
# Out:
# 2010121212

# %%
plays.to_clipboard(sep='\t')

# %%
drives.to_clipboard(sep='\t')

# %%
df3['playerName'].fillna(1)
# Out:
# 0                IND
# 1                IND
# 2                BUF
# 3         S.Hauschka
# 4       C.McLaughlin
# 5          C.Hedlund
# 6         S.Hauschka
# 7         S.Hauschka
# 8         S.Hauschka
# 9          R.Sanchez
# 10      C.McLaughlin
# 11         C.Hedlund
# 12         C.Hedlund
# 13      C.McLaughlin
# 14         C.Hedlund
# 15        S.Hauschka
# 16      C.McLaughlin
# 17         C.Hedlund
# 18        S.Hauschka
# 19        S.Hauschka
# 20        S.Hauschka
# 21         R.Sanchez
# 22      C.McLaughlin
# 23         C.Hedlund
# 24         C.Hedlund
# 25      C.McLaughlin
# 26         C.Hedlund
# 27                 1
# 28                 1
# 29                 1
#             ...
# 1093               1
# 1094        T.Yeldon
# 1095             IND
# 1096        P.Walker
# 1097             BUF
# 1098             BUF
# 1099             IND
# 1100             IND
# 1101             BUF
# 1102               1
# 1103               1
# 1104             BUF
# 1105             IND
# 1106             IND
# 1107         S.Perry
# 1108         C.Kelly
# 1109          C.Wade
# 1110       C.Hedlund
# 1111    C.McLaughlin
# 1112       C.Hedlund
# 1113       C.Hedlund
# 1114       C.Hedlund
# 1115    C.McLaughlin
# 1116       C.Hedlund
# 1117       C.Hedlund
# 1118       R.Sanchez
# 1119             IND
# 1120               1
# 1121               1
# 1122             IND
# Name: playerName, Length: 1123, dtype: object

# %%
z=df3.iloc[1010,1]

# %%
# plays['dupeindex']=plays['playerName']+' ' + plays['play'].astype(str)+' ' + plays['statId'].astype(str)+' '+plays['drive']+' '+ plays['gid']+' '+ plays['field']

# %%
# plays[plays['dupeindex'].duplicated(keep=False)].to_clipboard(sep='\t')

# %%
df2
# Out:
#      sequence clubcode   playerName  statId  yards    playerid  play drive  \
# 0           1       SD    N.Kaeding      41     65  00-0022737    36     1
# 1           1       SD    N.Kaeding      41     65  00-0022737    36     1
# 2           2       KC  D.McCluster      45     16  00-0027651    36     1
# 3           2       KC  D.McCluster      45     16  00-0027651    36     1
# 4           3       SD      B.Siler      79      0  00-0025627    36     1
# ..        ...      ...          ...     ...    ...         ...   ...   ...
# 852         5       KC       L.Pope     113     -2  00-0024287  3311    19
# 853         2       KC      T.Palko      10     -1  00-0024812  3335    19
# 854         2       KC      T.Palko      10     -1  00-0024812  3335    19
# 855         1       KC                    7      0           0  3335    19
# 856         1       KC                    7      0           0  3335    19
#
#                                            description         gid posteam  \
# 0    N.Kaeding kicks 65 yards from SD 30 to KC 5. D...  2010121212      SD
# 1    N.Kaeding kicks 65 yards from SD 30 to KC 5. D...  2010121212      SD
# 2    N.Kaeding kicks 65 yards from SD 30 to KC 5. D...  2010121212      SD
# 3    N.Kaeding kicks 65 yards from SD 30 to KC 5. D...  2010121212      SD
# 4    N.Kaeding kicks 65 yards from SD 30 to KC 5. D...  2010121212      SD
# ..                                                 ...         ...     ...
# 852  (:55) T.Palko pass short left to L.Pope to KC ...  2010121212      KC
# 853  (:14) T.Palko kneels, dead ball declared at KC...  2010121212      KC
# 854  (:14) T.Palko kneels, dead ball declared at KC...  2010121212      KC
# 855  (:14) T.Palko kneels, dead ball declared at KC...  2010121212      KC
# 856  (:14) T.Palko kneels, dead ball declared at KC...  2010121212      KC
#
#            cat             fields                            desc  \
# 0      kicking        kicking_tot                   Kickoff yards
# 1      kicking        kicking_yds                   Kickoff yards
# 2      kickret        kickret_ret            Kickoff return yards
# 3      kickret        kickret_yds            Kickoff return yards
# 4      defense        defense_tkl                     Solo tackle
# ..         ...                ...                             ...
# 852  receiving  receiving_yac_yds  Yardage gained after the catch
# 853    rushing        rushing_att                   Rushing yards
# 854    rushing        rushing_yds                   Rushing yards
# 855       team     third_down_att         3rd down attempt failed
# 856       team  third_down_failed         3rd down attempt failed
#
#                                                   long
# 0                          Kickoff and length of kick.
# 1                          Kickoff and length of kick.
# 2                            Kickoff return and yards.
# 3                            Kickoff return and yards.
# 4    Tackle with no assists. Note: There are no off...
# ..                                                 ...
# 852  Yardage from where the ball was caught until t...
# 853    Rushing yards and credit for a rushing attempt.
# 854    Rushing yards and credit for a rushing attempt.
# 855  3rd down play did not result in a first down o...
# 856  3rd down play did not result in a first down o...
#
# [857 rows x 15 columns]

# %%
df2[df2['statId']==6]
# Out:
#      sequence clubcode playerName  statId  yards playerid  play drive  \
# 58          2       SD                  6      0        0   239     2
# 59          2       SD                  6      0        0   239     2
# 60          2       SD                  6      0        0   239     2
# 79          2       SD                  6      0        0   305     2
# 80          2       SD                  6      0        0   305     2
# 81          2       SD                  6      0        0   305     2
# 99          2       SD                  6      0        0   368     2
# 100         2       SD                  6      0        0   368     2
# 101         2       SD                  6      0        0   368     2
# 276         2       SD                  6      0        0   950     6
# 277         2       SD                  6      0        0   950     6
# 278         2       SD                  6      0        0   950     6
# 393         2       SD                  6      0        0  1379     8
# 394         2       SD                  6      0        0  1379     8
# 395         2       SD                  6      0        0  1379     8
# 498         2       SD                  6      0        0  1764    10
# 499         2       SD                  6      0        0  1764    10
# 500         2       SD                  6      0        0  1764    10
# 514         2       SD                  6      0        0  1830    10
# 515         2       SD                  6      0        0  1830    10
# 516         2       SD                  6      0        0  1830    10
# 679         2       SD                  6      0        0  2571    16
# 680         2       SD                  6      0        0  2571    16
# 681         2       SD                  6      0        0  2571    16
# 716         2       SD                  6      0        0  2697    16
# 717         2       SD                  6      0        0  2697    16
# 718         2       SD                  6      0        0  2697    16
# 784         2       SD                  6      0        0  3040    18
# 785         2       SD                  6      0        0  3040    18
# 786         2       SD                  6      0        0  3040    18
# 801         2       SD                  6      0        0  3126    18
# 802         2       SD                  6      0        0  3126    18
# 803         2       SD                  6      0        0  3126    18
#
#                                            description         gid posteam  \
# 58   (10:22) (Shotgun) V.Jackson left end pushed ob...  2010121212      SD
# 59   (10:22) (Shotgun) V.Jackson left end pushed ob...  2010121212      SD
# 60   (10:22) (Shotgun) V.Jackson left end pushed ob...  2010121212      SD
# 79   (8:29) (Shotgun) P.Rivers right end to KC 32 f...  2010121212      SD
# 80   (8:29) (Shotgun) P.Rivers right end to KC 32 f...  2010121212      SD
# 81   (8:29) (Shotgun) P.Rivers right end to KC 32 f...  2010121212      SD
# 99   (6:23) (Shotgun) P.Rivers pass short right to ...  2010121212      SD
# 100  (6:23) (Shotgun) P.Rivers pass short right to ...  2010121212      SD
# 101  (6:23) (Shotgun) P.Rivers pass short right to ...  2010121212      SD
# 276  (9:48) (Shotgun) P.Rivers pass short right to ...  2010121212      SD
# 277  (9:48) (Shotgun) P.Rivers pass short right to ...  2010121212      SD
# 278  (9:48) (Shotgun) P.Rivers pass short right to ...  2010121212      SD
# 393  (1:11) (Shotgun) P.Rivers pass short left to D...  2010121212      SD
# 394  (1:11) (Shotgun) P.Rivers pass short left to D...  2010121212      SD
# 395  (1:11) (Shotgun) P.Rivers pass short left to D...  2010121212      SD
# 498  (14:11) (Shotgun) P.Rivers pass short left to ...  2010121212      SD
# 499  (14:11) (Shotgun) P.Rivers pass short left to ...  2010121212      SD
# 500  (14:11) (Shotgun) P.Rivers pass short left to ...  2010121212      SD
# 514  (12:00) (Shotgun) P.Rivers pass short left to ...  2010121212      SD
# 515  (12:00) (Shotgun) P.Rivers pass short left to ...  2010121212      SD
# 516  (12:00) (Shotgun) P.Rivers pass short left to ...  2010121212      SD
# 679  (13:19) (Shotgun) P.Rivers pass deep middle to...  2010121212      SD
# 680  (13:19) (Shotgun) P.Rivers pass deep middle to...  2010121212      SD
# 681  (13:19) (Shotgun) P.Rivers pass deep middle to...  2010121212      SD
# 716  (10:55) (Shotgun) P.Rivers pass short middle t...  2010121212      SD
# 717  (10:55) (Shotgun) P.Rivers pass short middle t...  2010121212      SD
# 718  (10:55) (Shotgun) P.Rivers pass short middle t...  2010121212      SD
# 784  (5:38) (Shotgun) D.Sproles up the middle to KC...  2010121212      SD
# 785  (5:38) (Shotgun) D.Sproles up the middle to KC...  2010121212      SD
# 786  (5:38) (Shotgun) D.Sproles up the middle to KC...  2010121212      SD
# 801  (3:23) R.Mathews right end for 15 yards, TOUCH...  2010121212      SD
# 802  (3:23) R.Mathews right end for 15 yards, TOUCH...  2010121212      SD
# 803  (3:23) R.Mathews right end for 15 yards, TOUCH...  2010121212      SD
#
#          cat                  fields                        desc  \
# 58      team          third_down_att  3rd down attempt converted
# 59      team         third_down_conv  3rd down attempt converted
# 60   defense  third_down_stop_failed  3rd down attempt converted
# 79      team          third_down_att  3rd down attempt converted
# 80      team         third_down_conv  3rd down attempt converted
# 81   defense  third_down_stop_failed  3rd down attempt converted
# 99      team          third_down_att  3rd down attempt converted
# 100     team         third_down_conv  3rd down attempt converted
# 101  defense  third_down_stop_failed  3rd down attempt converted
# 276     team          third_down_att  3rd down attempt converted
# 277     team         third_down_conv  3rd down attempt converted
# 278  defense  third_down_stop_failed  3rd down attempt converted
# 393     team          third_down_att  3rd down attempt converted
# 394     team         third_down_conv  3rd down attempt converted
# 395  defense  third_down_stop_failed  3rd down attempt converted
# 498     team          third_down_att  3rd down attempt converted
# 499     team         third_down_conv  3rd down attempt converted
# 500  defense  third_down_stop_failed  3rd down attempt converted
# 514     team          third_down_att  3rd down attempt converted
# 515     team         third_down_conv  3rd down attempt converted
# 516  defense  third_down_stop_failed  3rd down attempt converted
# 679     team          third_down_att  3rd down attempt converted
# 680     team         third_down_conv  3rd down attempt converted
# 681  defense  third_down_stop_failed  3rd down attempt converted
# 716     team          third_down_att  3rd down attempt converted
# 717     team         third_down_conv  3rd down attempt converted
# 718  defense  third_down_stop_failed  3rd down attempt converted
# 784     team          third_down_att  3rd down attempt converted
# 785     team         third_down_conv  3rd down attempt converted
# 786  defense  third_down_stop_failed  3rd down attempt converted
# 801     team          third_down_att  3rd down attempt converted
# 802     team         third_down_conv  3rd down attempt converted
# 803  defense  third_down_stop_failed  3rd down attempt converted
#
#                                                   long
# 58   3rd down play resulted in a first down or touc...
# 59   3rd down play resulted in a first down or touc...
# 60   3rd down play resulted in a first down or touc...
# 79   3rd down play resulted in a first down or touc...
# 80   3rd down play resulted in a first down or touc...
# 81   3rd down play resulted in a first down or touc...
# 99   3rd down play resulted in a first down or touc...
# 100  3rd down play resulted in a first down or touc...
# 101  3rd down play resulted in a first down or touc...
# 276  3rd down play resulted in a first down or touc...
# 277  3rd down play resulted in a first down or touc...
# 278  3rd down play resulted in a first down or touc...
# 393  3rd down play resulted in a first down or touc...
# 394  3rd down play resulted in a first down or touc...
# 395  3rd down play resulted in a first down or touc...
# 498  3rd down play resulted in a first down or touc...
# 499  3rd down play resulted in a first down or touc...
# 500  3rd down play resulted in a first down or touc...
# 514  3rd down play resulted in a first down or touc...
# 515  3rd down play resulted in a first down or touc...
# 516  3rd down play resulted in a first down or touc...
# 679  3rd down play resulted in a first down or touc...
# 680  3rd down play resulted in a first down or touc...
# 681  3rd down play resulted in a first down or touc...
# 716  3rd down play resulted in a first down or touc...
# 717  3rd down play resulted in a first down or touc...
# 718  3rd down play resulted in a first down or touc...
# 784  3rd down play resulted in a first down or touc...
# 785  3rd down play resulted in a first down or touc...
# 786  3rd down play resulted in a first down or touc...
# 801  3rd down play resulted in a first down or touc...
# 802  3rd down play resulted in a first down or touc...
# 803  3rd down play resulted in a first down or touc...

# %%
play_piv=plays.pivot_table(index=['clubcode', 'playerName', 'statId', 'yards',
       'play', 'drive', 'description', 'gid', 'posteam', 'cat',
       'field'],aggfunc={'playerid':lambda x: ','.join(x),
                                               'points':np.mean}).reset_index()

pp2=play_piv.pivot_table(index=['playerName','clubcode','gid'],values='points',aggfunc=sum).reset_index()

dpiv=drives.pivot_table(index=['defteam','defteam','gid'],values='points',aggfunc=sum).reset_index()

dpiv.columns=pp2.columns

fullpiv=pd.concat([pp2,dpiv]).pivot_table(index=['playerName','clubcode','gid'],values='points',aggfunc=sum).reset_index()

# %%
fullpiv.to_clipboard(sep='\t')

# %%
drives[drives['defteam']=='MIN'].to_clipboard(sep='\t')

# %%
plays[plays['playerName']=='MIN'].dropna().pivot_table(index='field',values='points',aggfunc=sum).to_clipboard()

# %%
plays[plays['playerName']=='MIN'].dropna()
